# %%
import pandas as pd
schema_raw = pd.read_csv('stackoverflow-developer-survey-2020/survey_results_schema.csv', index_col='Column').QuestionText

# %%
import opendatasets as od

# %%
od.download('stackoverflow-developer-survey-2020')
# Out:
# Using downloaded and verified file: .\stackoverflow-developer-survey-2020\survey_results_public.csv
# Using downloaded and verified file: .\stackoverflow-developer-survey-2020\survey_results_schema.csv
# Using downloaded and verified file: .\stackoverflow-developer-survey-2020\README.txt

# %%
survey_raw_df = pd.read_csv('stackoverflow-developer-survey-2020/survey_results_public.csv')

# %%
schema_fname = 'stackoverflow-developer-survey-2020/survey_results_schema.csv'
schema_raw = pd.read_csv(schema_fname, index_col='Column').QuestionText

# %%
schema_raw['YearsCodePro']
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %%
selected_columns = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    # Programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
survey_df=survey_raw_df[selected_columns].copy()

# %%
schema=schema_raw[selected_columns]

# %%
survey_df.shape
# Out:
# (64461, 20)

# %%
survey_df.Age1stCode.unique()
# Out:
# array(['13', '19', '15', '18', '16', '14', '12', '20', '42', '8', '25',
#        '22', '30', '17', '21', '10', '46', '9', '7', '11', '6', nan, '31',
#        '29', '5', 'Younger than 5 years', '28', '38', '23', '27', '41',
#        '24', '53', '26', '35', '32', '40', '33', '36', '54', '48', '56',
#        '45', '44', '34', 'Older than 85', '39', '51', '68', '50', '37',
#        '47', '43', '52', '85', '64', '55', '58', '49', '76', '72', '73',
#        '83', '63'], dtype=object)

# %%
survey_df['Age1stCode']=pd.to_numeric(survey_df.Age1stCode,errors='coerce')

# %%
survey_df['YearsCode']=pd.to_numeric(survey_df.YearsCode,errors='coerce')

# %%
survey_df['YearsCodePro']=pd.to_numeric(survey_df.YearsCodePro,errors='coerce')

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45446.000000  57473.000000  56784.000000  44133.000000  41151.000000
# mean      30.834111     15.476572     12.782051      8.869667     40.782174
# std        9.585392      5.114081      9.490657      7.759961     17.816383
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %%
survey_df.drop(survey_df[survey_df.Age<10].index, inplace=True)

# %%
survey_df.drop(survey_df[survey_df.Age>100].index, inplace=True)

# %%
survey_df.drop(survey_df[survey_df.WorkWeekHrs>140].index, inplace=True)

# %%
survey_df.where(~(survey_df.Gender.str.contains(';', na=False)), np.nan, inplace=True)

# %%
import numpy as np

# %%
survey_df.sample(10)
# Out:
#               Country   Age Gender  \
# 10522           India  34.0    Man
# 21663     Netherlands  32.0    Man
# 50962          Canada  49.0    Man
# 41105     Netherlands   NaN    NaN
# 19794  United Kingdom  45.0    Man
# 33636   United States  34.0    Man
# 21049          Poland  30.0    Man
# 41994          France   NaN    NaN
# 40929           India   NaN    NaN
# 48852          Canada   NaN    NaN
#
#                                                  EdLevel  \
# 10522       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 21663    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 50962         Other doctoral degree (Ph.D., Ed.D., etc.)
# 41105  Some college/university study without earning ...
# 19794       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33636    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 21049       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 41994                                                NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

sns.set_style('darkgrid')

# %%
top_countries=survey_df.Country.value_counts().head(15)
top_countries
# Out:
# United States         12371
# India                  8364
# United Kingdom         3881
# Germany                3864
# Canada                 2175
# France                 1884
# Brazil                 1804
# Netherlands            1332
# Poland                 1259
# Australia              1199
# Spain                  1157
# Italy                  1115
# Russian Federation     1085
# Sweden                  879
# Pakistan                802
# Name: Country, dtype: int64

# %%
sns.barplot(top_countries.index, top_countries)
plt.title(schema.Country)
plt.xticks(rotation=75)
plt.figure(figsize=(200,67));
# Out:
# c:\Users\QSS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.title('distribution of age')
plt.xlabel('Age')
plt.ylabel('number of respondents')

plt.hist(survey_df.Age,bins=np.arange(10,80,5),color='purple');

# %%
plt.figure(figsize=(12,6))
plt.title(schema.Gender)
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=180);

# %%
gender_counts = survey_df.Gender.value_counts()
gender_counts
# Out:
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: Gender, dtype: int64

# %%
sns.countplot(y=survey_df.EdLevel)
plt.title(schema['EdLevel'])
plt.xticks(rotation=75);

# %%
schema.Employment
# Out:
# 'Which of the following best describes your current employment status?'

# %%
(survey_df.Employment.value_counts(normalize=True, ascending=True)*100).plot(kind='barh', color='g')
plt.title(schema.Employment)
plt.xlabel('Percentage');

# %%
survey_df.DevType.value_counts()
# Out:
# Developer, full-stack                                                                                                                                                           4396
# Developer, back-end                                                                                                                                                             3056
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                  2214
# Developer, back-end;Developer, full-stack                                                                                                                                       1465
# Developer, front-end                                                                                                                                                            1390
# ...

# %%
def split_multicolumn(col_series):
    result_df = col_series.to_frame()
    options = []
    # Iterate over the column
    for idx, value  in col_series[col_series.notnull()].iteritems():
        # Break each value into list of options
        for option in value.split(';'):
            # Add the option as a column to result
            if not option in result_df.columns:
                options.append(option)
                result_df[option] = False
            # Mark the value in the option column as True
            result_df.at[idx, option] = True
    return result_df[options]

# %%
dev_type_df=split_multicolumn(survey_df.DevType)

# %%
dev_type_df
# Out:
#        Developer, desktop or enterprise applications  Developer, full-stack  \
# 0                                               True                   True
# 1                                              False                   True
# 2                                              False                  False
# 3                                              False                  False
# 4                                              False                  False
# ...                                              ...                    ...
# 64456                                          False                  False
# 64457                                          False                  False
# 64458                                          False                  False
# 64459                                          False                  False
# 64460                                          False                  False
#
# ...

# %%
dev_total=dev_type_df.sum().sort_values(ascending=False)

# %%
dev_total
# Out:
# Developer, back-end                              26996
# Developer, full-stack                            26915
# Developer, front-end                             18128
# Developer, desktop or enterprise applications    11687
# Developer, mobile                                 9406
# DevOps specialist                                 5915
# Database administrator                            5658
# Designer                                          5262
# System administrator                              5185
# Developer, embedded applications or devices       4701
# Data or business analyst                          3970
# Data scientist or machine learning specialist     3939
# Developer, QA or test                             3893
# Engineer, data                                    3700
# Academic researcher                               3502
# Educator                                          2895
# Developer, game or graphics                       2751
# ...

# %%
survey_df.LanguageWorkedWith
# Out:
# 0                                   C#;HTML/CSS;JavaScript
# 1                                         JavaScript;Swift
# 2                                 Objective-C;Python;Swift
# 3                                                      NaN
# 4                                        HTML/CSS;Ruby;SQL
#                                ...
# 64456                                                  NaN
# 64457    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                  NaN
# 64459                                             HTML/CSS
# 64460                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64306, dtype: object

# %%
language_work_df=split_multicolumn(survey_df.LanguageWorkedWith)
language_work_df
# Out:
#           C#  HTML/CSS  JavaScript  Swift  Objective-C  Python   Ruby    SQL  \
# 0       True      True        True  False        False   False  False  False
# 1      False     False        True   True        False   False  False  False
# 2      False     False       False   True         True    True  False  False
# 3      False     False       False  False        False   False  False  False
# 4      False      True       False  False        False   False   True   True
# ...      ...       ...         ...    ...          ...     ...    ...    ...
# 64456  False     False       False  False        False   False  False  False
# 64457   True      True        True   True         True    True   True   True
# 64458  False     False       False  False        False   False  False  False
# 64459  False      True       False  False        False   False  False  False
# 64460   True      True        True  False        False   False  False   True
#
# ...

# %%
language_work_percentage=language_work_df.mean().sort_values(ascending=False)*100
language_work_percentage
# Out:
# JavaScript               59.893323
# HTML/CSS                 55.801947
# SQL                      48.444935
# Python                   39.001026
# Java                     35.618760
# Bash/Shell/PowerShell    29.239884
# C#                       27.803004
# PHP                      23.130035
# TypeScript               22.461357
# C++                      21.114670
# C                        19.236152
# Go                        7.758219
# Kotlin                    6.887382
# Ruby                      6.229590
# Assembly                  5.447392
# VBA                       5.394520
# Swift                     5.226573
# R                         5.064846
# Rust                      4.498803
# Objective-C               3.603085
# Dart                      3.517557
# Scala                     3.150561
# Perl                      2.757130
# Haskell                   1.861413
# Julia                     0.782198
# dtype: float64

# %%
sns.barplot(language_work_percentage,language_work_percentage.index)
plt.title('language used in the past years')
plt.xlabel('count');
# Out:
# c:\Users\QSS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
language_interested_df=split_multicolumn(survey_df.LanguageDesireNextYear)
language_interested_percentage=language_interested_df.mean().sort_values(ascending=False)*100

# %%
sns.barplot(language_interested_percentage,language_interested_percentage.index)
plt.title('language people are interested in learning next year')
plt.xlabel('count');
# Out:
# c:\Users\QSS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
language_loved_df=language_work_df & language_interested_df

# %%
language_loved_df
# Out:
#        Assembly  Bash/Shell/PowerShell      C     C#    C++   Dart     Go  \
# 0         False                  False  False   True  False  False  False
# 1         False                  False  False  False  False  False  False
# 2         False                  False  False  False  False  False  False
# 3         False                  False  False  False  False  False  False
# 4         False                  False  False  False  False  False  False
# ...         ...                    ...    ...    ...    ...    ...    ...
# 64456     False                  False  False  False  False  False  False
# 64457      True                   True   True   True   True   True   True
# 64458     False                  False  False  False  False  False  False
# 64459     False                  False  False  False  False  False  False
# 64460     False                  False  False   True  False  False  False
#
#        HTML/CSS  Haskell   Java  ...   Perl  Python      R   Ruby   Rust  \
# ...

# %%
language_loved_percentage=(language_loved_df.sum()*100/language_work_df.sum()).sort_values(ascending=False)

# %%
language_loved_percentage
# Out:
# Rust                     86.069824
# TypeScript               67.114373
# Python                   66.598884
# Kotlin                   62.813276
# Go                       62.176789
# Dart                     62.068966
# Julia                    61.431412
# C#                       59.623021
# Swift                    59.476346
# JavaScript               58.353888
# SQL                      56.607710
# Bash/Shell/PowerShell    53.688241
# HTML/CSS                 53.494594
# Scala                    53.257651
# Haskell                  51.378446
# R                        44.427387
# Java                     44.108273
# C++                      43.415820
# Ruby                     42.735896
# PHP                      37.232755
# C                        32.983023
# Assembly                 29.089352
# Perl                     28.369994
# Objective-C              23.133362
# VBA                      19.458057
# dtype: float64

# %%
sns.barplot(language_loved_percentage,language_loved_percentage.index)
plt.title('language people love the most')
plt.xlabel('count');
# Out:
# c:\Users\QSS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
countries_df=survey_df.groupby('Country')[['WorkWeekHrs']].mean().sort_values('WorkWeekHrs',ascending=False)

# %%
countries_df
# Out:
#                  WorkWeekHrs
# Country
# Kuwait             58.222222
# Iraq               52.153846
# Grenada            50.000000
# Maldives           47.300000
# Afghanistan        46.500000
# ...                      ...
# North Korea              NaN
# Saint Lucia              NaN
# Sierra Leone             NaN
# Solomon Islands          NaN
# Timor-Leste              NaN
#
# [183 rows x 1 columns]

# %%
high_response_countries_df=countries_df.loc[survey_df.Country.value_counts()>250].head(15)

# %%
high_response_countries_df
# Out:
#                WorkWeekHrs
# Country
# Iran             44.337748
# Israel           43.915094
# China            42.150000
# United States    41.802982
# Greece           41.402724
# Viet Nam         41.391667
# South Africa     41.023460
# Turkey           40.982143
# Sri Lanka        40.612245
# New Zealand      40.457551
# Belgium          40.444444
# Canada           40.208837
# Hungary          40.194340
# Bangladesh       40.097458
# India            40.090603

# %%
sns.scatterplot('Age','YearsCodePro', hue='hobbyist' ,data='survey_df')
plt.xlabel('Age')
plt.ylabel('years of professional coding experience');
# Out:
# c:\Users\QSS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\QSS\Desktop\test\project_python.ipynb Cell 52 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/QSS/Desktop/test/project_python.ipynb#ch0000051?line=0'>1</a> sns.scatterplot('Age','YearsCodePro', hue='hobbyist' ,data='survey_df')
#       <a href='vscode-notebook-cell:/c%3A/Users/QSS/Desktop/test/project_python.ipynb#ch0000051?line=1'>2</a> plt.xlabel('Age')
# ...

# %%
survey_df.Age
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3        25.0
# 4        31.0
#          ...
# 64456     NaN
# 64457     NaN
# 64458     NaN
# 64459     NaN
# 64460     NaN
# Name: Age, Length: 64306, dtype: float64

# %%
plt.title(schema.Age1stCode)
sns.distplot(survey_df.Age1stCode);
# Out:
# c:\Users\QSS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
